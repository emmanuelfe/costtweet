# %% [markdown]
# # Costweet : CNN + Fasttext
#
# Ce notebook classe des phrases en 3 catégories "cher", "moyen","éco".
#
# Il fait partie d'une série de notebook permettant de comparer différentes approches de classification en faisant varier les architectures de réseaux de neurones et les méthodes d'encodification des textes.
#
# Il s'appuie sur un ensemble de données de petite taille.
#
# Cet ensemble est vectorisé en utilisant la librairie fasttext de facebook (camdial.org).
#
# Le réseau de neurones est architecturé de trois couches 2 de type convolution. Ce réseau est identique à celui utilisé par le notebook intitulé "Costweet : CNN + manuel encoding"
#
# L'accuracy obtenu le 7 février 2018  est de 92,7% à comparer aux 85% obtenus avec avec un réseau sans convolution.
#
# Keras uses tensorflow uses sklearn uses numpy and pandas
#
# Ce notebook s'inspire fortement du code de François Chollet https://github.com/keras-team/keras/blob/master/examples/pretrained_word_embeddings.py

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, Embedding, Conv1D, Input, GlobalMaxPooling1D, MaxPooling1D
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import text_to_word_sequence
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
from keras.models import Model
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
#for fasttext
from __future__ import print_function
from gensim.models import KeyedVectors
# Out:
# Using TensorFlow backend.
# d:\code\ml\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %% [markdown]
#  DATA PROCESS
#  les données ont été saisies sous excel et sauvegardées en csv utf-8 bizarement avec l'option séparateur virgules de microsoft

# %%
def getDataset():
	dataset = pd.read_csv("RuleCout3.csv", delimiter=";", encoding='utf-8')
	#print ( 'dataset loaded with shape',dataset.shape)
	X = dataset['text']
	Y = dataset['class']
	dataset.set_index('text') #pour avoir les classes dans un ordre quelconque
	return dataset, X, Y

# utile pour les colonnes sur une ligne et afficher toutes les lignes
pd.set_option('display.width', 200)
pd.set_option('display.max_rows', 1000)

# on ajoutera peu à peu de nouvelles colonnes au dataset 
dataset, X, Y = getDataset()
print(dataset)
# Out:
#                               text  class
# 0            à la bonne franquette    éco
# 1                  à prix modique     éco
# 2          aucun problème d'argent   cher
# 3                      avantageux     éco
# 4                    bas de gamme     éco
# 5                         bas prix    éco
# 6                bistrot pas cher     éco
# 7                              bon   cher
# 8                     bon japonais   cher
# 9                      bon marché     éco
# 10       bon rapport qualité prix   moyen
# 11                         burger     éco
# 12                   burger classe  moyen
# 13                         cantine    éco
# 14                         caviar    cher
# 15          ce n'est pas important  moyen
# 16           cent euros pour deux    cher
# 17            c'est la fin du mois    éco
# 18                           cher    cher
# 19             dix euros pour deux    éco
# 20                             éco    éco
# 21                     économique     éco
# 22                  entre 10 et 20    éco
# 23           entre vingt et trente  moyen
# 24                          frites    éco
# 25                  gastronomique    cher
# 26                  haut de gamme    cher
# 27                j’ai les moyens    cher
# 28              j'aime burger king    éco
# 29                 j'aime les œufs    éco
# 30                        japonais    éco
# 31                  je m’en fiche    cher
# 32                   je m’en fous    cher
# 33                   je m'en fiche  moyen
# 34                   je m'en fiche  moyen
# 35              je n'ai pas un sou    éco
# 36                  je suis riche    cher
# 37               jusqu'à cinquante   cher
# 38                           kebab    éco
# 39       le meilleur des meilleurs   cher
# 40                           luxe    cher
# 41                        luxueux    cher
# 42           ma bourse est pleine    cher
# 43                          mac do    éco
# 44                       maccaroni    éco
# 45          menu pas cher le midi     éco
# 46                        modeste     éco
# 47                        modique     éco
# 48            moins de cent euros    cher
# 49             moins de dix euros     éco
# 50                 moins de quinze    éco
# 51          moins de trente euros   moyen
# 52                 moins de vingt     éco
# 53           moins de vingt euros     éco
# 54                  moyen de gamme  moyen
# 55            ni cher ni pas cher   moyen
# 56                   pas bien cher    éco
# 57                  pas bon marché   cher
# 58                       pas cher     éco
# 59                pas cher du tout    éco
# 60               pas cher du tout     éco
# 61                        pas chic    éco
# 62                    pas pas cher   cher
# 63                pas pas pas cher    éco
# 64                   pas trop cher    éco
# 65                   pas trop cher    éco
# 66                  pas un routier   cher
# 67           pas un trois étoiles   moyen
# 68                 pas une cantine   cher
# 69                           pates    éco
# 70                    petit bistro    éco
# 71                   petit troquet    éco
# 72                petite brasserie    éco
# 73            peu importe le prix   moyen
# 74                     peu onéreux    éco
# 75                           pizza    éco
# 76                  plus de vingt    cher
# 77                     plutôt bien   cher
# 78                     plutôt cher   cher
# 79            plutôt de la qualité   cher
# 80                 plutôt pas cher    éco
# 81                  plutôt pas mal   cher
# 82              plutôt un troquet     éco
# 83                         qualité   cher
# 84                           ramen    éco
# 85                          rapide    éco
# 86                           soupe    éco
# 87                       standing    cher
# 88                      super cher   cher
# 89                 super standing    cher
# 90                          sushis    éco
# 91               très bas de gamme    éco
# 92                très bon marché     éco
# 93                       très cher   cher
# 94                 très économique    éco
# 95              très haut de gamme   cher
# 96              très haut de gamme   cher
# 97                   très modeste     éco
# 98                  très peu cher     éco
# 99                          truffe   cher
# 100                  un bon repas    cher
# 101      un endroit en plein Paris   cher
# 102       un menu moins de quinze     éco
# 103               un plat à vingt    cher
# 104                  un portuguais    éco
# 105            un restau bien côté   cher
# 106       un restau dans la creuse    éco
# 107           un restau de qualité   cher
# 108        un restau pour conclure   cher
# 109       un restaurant de routier    éco
# 110           un restaurant étoilé   cher
# 111       un resto pour le gratin    cher
# 112                       un self     éco
# 113                   un très bon    cher
# 114              un truc abordable    éco
# 115                un truc chicos    cher
# 116                 un truc classe   cher
# 117                       vil prix    éco
# 118                   vraiment bon   cher
# 119               vraiment luxueux   cher
# 120              vraiment pas cher    éco
# 121             vraiment très cher   cher
# 122                      peu cher     éco
# 123  pas plus de cent par personne   cher
# 124  plutôt spacieux et tranquille   cher
# 125                        du bio   moyen
# 126                         huitre   cher
# 127      un restaurant de poissons   cher
# 128           un restaurant rapide    éco
# 129            un grand restaurant   cher
# 130           un restaurant grand    cher
# 131                     prix moyen  moyen
# 132             mauvais restaurant    éco
# 133            je veux bien manger   cher
# 134             des produits frais   cher
# 135                   des produits   flou
# 136                     des pizzas    éco
# 137    un restaurant avec terrasse   cher
# 138    un restaurant avec ambiance   cher

# %% [markdown]
# # Chargement de fasttext
# Fasttext needs 10 minutes to be loaded
# C'est le temps de chargement du dataset fasttextwiki.fr.vec donne un vocabulaire de 1 115 449 mots et donc autant de vecteurs.
#
# Il vaudrait mieux charger avecle .bin ce serait plus rapide. Le .bin pèse 5 gigas-octets !
#
# Ces vecteurs ont été valorisé en utilisant l'approche skip-gram décrite dans Bojanowski et al. (2016) en utilisant les paramètres par défaut.
#
# La dimension de ces vesteurs est de 300.
#
# We are publishing pre-trained word vectors for 294 languages, trained on Wikipedia using fastText.
# These vectors in dimension 300 were obtained using the skip-gram model described in Bojanowski et al. (2016) with default parameters.
#
# origine #https://blog.manash.me/how-to-use-pre-trained-word-vectors-from-facebooks-fasttext-a71e6d55f27

# %%
# Creating the model
fr_model = KeyedVectors.load_word2vec_format('../data/fasttextwiki.fr.vec')

# Getting the tokens 
words = []
for word in fr_model.vocab:
    words.append(word)

# Printing out number of tokens available
print("Number of Tokens: {}".format(len(words)))
# Out:
# Number of Tokens: 1152449

# %%
# encode retourne un vecteur en fonction d'un mot
def score(word):
    return  fr_model[word]

vector_troquet = score('troquet')

print ( 'score troquet', vector_troquet, len(vector_troquet))
# Out:
# score troquet [-0.28589    -0.26518     0.076356   -0.017638    0.20075    -0.037748
#  -0.20504     0.22178    -0.16894     0.4035     -0.34198     0.037411
#  -0.081518   -0.1229     -0.51538     0.0088103   0.084543   -0.082374
#  -0.38133    -0.07603     0.10483    -0.019706   -0.04029     0.37365
#  -0.37959    -0.54548    -0.31914    -0.31262    -0.060444   -0.053712
#   0.43251    -0.1079      0.23003    -0.066676   -0.29099    -0.081674
#  -0.20116    -0.32752     0.091499    0.081911    0.051361    0.076685
#  -0.071495   -0.070764    0.28938    -0.12803     0.066035    0.097801
#  -0.016806    0.015525    0.084922   -0.23528    -0.017823    0.4899
#  -0.15586    -0.14952    -0.30836     0.12642     0.10689     0.10892
#  -0.17307     0.36345     0.10455     0.60661    -0.33281    -0.18994
#   0.20595     0.074113    0.1325     -0.30423     0.076651    0.18055
#  -0.29682    -0.17862    -0.43857    -0.002312    0.47742     0.096643
#  -0.32785    -0.067572    0.013655   -0.20559     0.49405    -0.18791
#   0.23757     0.00078463 -0.0018967  -0.17094     0.17633    -0.36571
#  -0.57031     0.20263    -0.47248     0.015689    0.2196     -0.20171
#  -0.12813     0.091247   -0.30764    -0.20275     0.0054345   0.43754
#  -0.09911     0.18562    -0.012149    0.15621     0.1475     -0.17386
#   0.16671    -0.11789    -0.20674    -0.13441     0.34854    -0.06831
#   0.34255    -0.29557     0.46448    -0.11529     0.24746     0.11094
#  -0.31188    -0.22475    -0.34043     0.46662    -0.12366     0.065277
#  -0.076198   -0.34101     0.14786     0.32995    -0.30792     0.15209
#   0.15168    -0.173      -0.22028    -0.33666     0.046093   -0.071187
#   0.053255    0.3018      0.15746    -0.099723   -0.061609   -0.1107
#   0.034687    0.17424     0.09169    -0.025352    0.028848   -0.23458
#  -0.16485     0.18112     0.019005   -0.18912    -0.30349    -0.015035
#   0.15468    -0.049885   -0.032433    0.28247    -0.1058     -0.18018
#  -0.0037209  -0.12696    -0.34568    -0.058093   -0.053964    0.26324
#   0.13053     0.12984    -0.057109   -0.19353     0.43222     0.044603
#   0.18991     0.45328     0.12752    -0.022051    0.015889    0.060179
#   0.066003   -0.23395     0.13357    -0.046691    0.1872      0.35959
#   0.045204   -0.22524     0.26214    -0.2001     -0.22272     0.006033
#   0.11303    -0.15875    -0.025181   -0.17015     0.071938    0.13508
#  -0.42219    -0.0093729  -0.20746     0.019521    0.34628    -0.0038888
#   0.09292     0.28045     0.11546     0.054858   -0.29406     0.25482
#   0.03263     0.19524     0.276      -0.16468    -0.50165    -0.16673
#   0.12032    -0.14054     0.0010075   0.1414     -0.1589     -0.1566
#  -0.12092    -0.00076705  0.029417    0.097159    0.46166    -0.33778
#   0.11563    -0.29209    -0.038051    0.15984     0.11784     0.10036
#  -0.37479    -0.19642    -0.2464     -0.32999    -0.23687     0.098631
#   0.021494   -0.092864   -0.047681    0.23411    -0.20374    -0.060221
#  -0.023229   -0.096956    0.11711    -0.13746    -0.07644     0.12871
#  -0.089494   -0.24969     0.55666    -0.11556     0.098391   -0.052547
#   0.18637     0.047959   -0.015993   -0.15159     0.17837     0.28867
#   0.051862   -0.076913    0.5693     -0.19128     0.2077     -0.013702
#  -0.011674   -0.13816     0.10234    -0.19084     0.070745    0.051003
#  -0.12125    -0.052968    0.13823    -0.19489    -0.023406   -0.093177
#   0.10516    -0.20099     0.0015353   0.3495      0.10003     0.10505
#  -0.046072   -0.05747     0.22315    -0.32031     0.37838    -0.16781
#  -0.13768     0.108      -0.27151    -0.052906   -0.12553    -0.19519   ] 300

# %%
#ai préféré utiliser le tokenizer de keras plutôt que celui de nltk car les valeurs filtrées par défaut comprennent l'apostrophe
#def tokenize(sentence):
#	tokens = text_to_word_sequence(sentence)
#	return tokens
	
#dataset['tokens']= dataset['text'].map(tokenize)
#dataset['tokens']

MAX_NUM_WORDS = 20000
MAX_SEQUENCE_LENGTH = 5
texts = dataset['text']
# finally, vectorize the text samples into a 2D integer tensor
tokenizer = Tokenizer(num_words=MAX_NUM_WORDS)
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)

#labels = to_categorical(np.asarray(labels))
print('Shape of data tensor:', data.shape)
#print('Shape of label tensor:', labels.shape)
dataset['tokens']= list(data)
dataset
# Out:
# Found 155 unique tokens.
# Shape of data tensor: (139, 5)
#                               text  class                   tokens
# 0            à la bonne franquette    éco      [0, 25, 15, 65, 66]
# 1                  à prix modique     éco       [0, 0, 25, 11, 34]
# 2          aucun problème d'argent   cher       [0, 0, 67, 68, 69]
# 3                      avantageux     éco         [0, 0, 0, 0, 70]
# 4                    bas de gamme     éco        [0, 0, 26, 4, 12]
# 5                         bas prix    éco        [0, 0, 0, 26, 11]
# 6                bistrot pas cher     éco         [0, 0, 71, 2, 3]
# 7                              bon   cher          [0, 0, 0, 0, 6]
# 8                     bon japonais   cher         [0, 0, 0, 6, 35]
# 9                      bon marché     éco         [0, 0, 0, 6, 27]
# 10       bon rapport qualité prix   moyen       [0, 6, 72, 16, 11]
# 11                         burger     éco         [0, 0, 0, 0, 28]
# 12                   burger classe  moyen        [0, 0, 0, 28, 36]
# 13                         cantine    éco         [0, 0, 0, 0, 37]
# 14                         caviar    cher         [0, 0, 0, 0, 73]
# 15          ce n'est pas important  moyen       [0, 74, 75, 2, 76]
# 16           cent euros pour deux    cher      [0, 29, 13, 17, 38]
# 17            c'est la fin du mois    éco     [77, 15, 78, 18, 79]
# 18                           cher    cher          [0, 0, 0, 0, 3]
# 19             dix euros pour deux    éco      [0, 39, 13, 17, 38]
# 20                             éco    éco         [0, 0, 0, 0, 80]
# 21                     économique     éco         [0, 0, 0, 0, 40]
# 22                  entre 10 et 20    éco      [0, 41, 81, 30, 82]
# 23           entre vingt et trente  moyen      [0, 41, 14, 30, 42]
# 24                          frites    éco         [0, 0, 0, 0, 83]
# 25                  gastronomique    cher         [0, 0, 0, 0, 84]
# 26                  haut de gamme    cher        [0, 0, 31, 4, 12]
# 27                j’ai les moyens    cher       [0, 0, 85, 43, 86]
# 28              j'aime burger king    éco       [0, 0, 44, 28, 87]
# 29                 j'aime les œufs    éco       [0, 0, 44, 43, 88]
# 30                        japonais    éco         [0, 0, 0, 0, 35]
# 31                  je m’en fiche    cher        [0, 0, 8, 45, 32]
# 32                   je m’en fous    cher        [0, 0, 8, 45, 89]
# 33                   je m'en fiche  moyen        [0, 0, 8, 46, 32]
# 34                   je m'en fiche  moyen        [0, 0, 8, 46, 32]
# 35              je n'ai pas un sou    éco        [8, 90, 2, 1, 91]
# 36                  je suis riche    cher        [0, 0, 8, 92, 93]
# 37               jusqu'à cinquante   cher        [0, 0, 0, 94, 95]
# 38                           kebab    éco         [0, 0, 0, 0, 96]
# 39       le meilleur des meilleurs   cher      [0, 19, 97, 20, 98]
# 40                           luxe    cher         [0, 0, 0, 0, 99]
# 41                        luxueux    cher         [0, 0, 0, 0, 47]
# 42           ma bourse est pleine    cher  [0, 100, 101, 102, 103]
# 43                          mac do    éco      [0, 0, 0, 104, 105]
# 44                       maccaroni    éco        [0, 0, 0, 0, 106]
# 45          menu pas cher le midi     éco      [48, 2, 3, 19, 107]
# 46                        modeste     éco         [0, 0, 0, 0, 49]
# 47                        modique     éco         [0, 0, 0, 0, 34]
# 48            moins de cent euros    cher        [0, 9, 4, 29, 13]
# 49             moins de dix euros     éco        [0, 9, 4, 39, 13]
# 50                 moins de quinze    éco         [0, 0, 9, 4, 50]
# 51          moins de trente euros   moyen        [0, 9, 4, 42, 13]
# 52                 moins de vingt     éco         [0, 0, 9, 4, 14]
# 53           moins de vingt euros     éco        [0, 9, 4, 14, 13]
# 54                  moyen de gamme  moyen        [0, 0, 51, 4, 12]
# 55            ni cher ni pas cher   moyen        [52, 3, 52, 2, 3]
# 56                   pas bien cher    éco         [0, 0, 2, 21, 3]
# 57                  pas bon marché   cher         [0, 0, 2, 6, 27]
# 58                       pas cher     éco          [0, 0, 0, 2, 3]
# 59                pas cher du tout    éco        [0, 2, 3, 18, 53]
# 60               pas cher du tout     éco        [0, 2, 3, 18, 53]
# 61                        pas chic    éco        [0, 0, 0, 2, 108]
# 62                    pas pas cher   cher          [0, 0, 2, 2, 3]
# 63                pas pas pas cher    éco          [0, 2, 2, 2, 3]
# 64                   pas trop cher    éco         [0, 0, 2, 54, 3]
# 65                   pas trop cher    éco         [0, 0, 2, 54, 3]
# 66                  pas un routier   cher         [0, 0, 2, 1, 55]
# 67           pas un trois étoiles   moyen      [0, 2, 1, 109, 110]
# 68                 pas une cantine   cher       [0, 0, 2, 111, 37]
# 69                           pates    éco        [0, 0, 0, 0, 112]
# 70                    petit bistro    éco       [0, 0, 0, 56, 113]
# 71                   petit troquet    éco        [0, 0, 0, 56, 57]
# 72                petite brasserie    éco      [0, 0, 0, 114, 115]
# 73            peu importe le prix   moyen     [0, 22, 116, 19, 11]
# 74                     peu onéreux    éco       [0, 0, 0, 22, 117]
# 75                           pizza    éco        [0, 0, 0, 0, 118]
# 76                  plus de vingt    cher        [0, 0, 58, 4, 14]
# 77                     plutôt bien   cher        [0, 0, 0, 10, 21]
# 78                     plutôt cher   cher         [0, 0, 0, 10, 3]
# 79            plutôt de la qualité   cher       [0, 10, 4, 15, 16]
# 80                 plutôt pas cher    éco         [0, 0, 10, 2, 3]
# 81                  plutôt pas mal   cher       [0, 0, 10, 2, 119]
# 82              plutôt un troquet     éco        [0, 0, 10, 1, 57]
# 83                         qualité   cher         [0, 0, 0, 0, 16]
# 84                           ramen    éco        [0, 0, 0, 0, 120]
# 85                          rapide    éco         [0, 0, 0, 0, 59]
# 86                           soupe    éco        [0, 0, 0, 0, 121]
# 87                       standing    cher         [0, 0, 0, 0, 60]
# 88                      super cher   cher         [0, 0, 0, 61, 3]
# 89                 super standing    cher        [0, 0, 0, 61, 60]
# 90                          sushis    éco        [0, 0, 0, 0, 122]
# 91               très bas de gamme    éco        [0, 5, 26, 4, 12]
# 92                très bon marché     éco         [0, 0, 5, 6, 27]
# 93                       très cher   cher          [0, 0, 0, 5, 3]
# 94                 très économique    éco         [0, 0, 0, 5, 40]
# 95              très haut de gamme   cher        [0, 5, 31, 4, 12]
# 96              très haut de gamme   cher        [0, 5, 31, 4, 12]
# 97                   très modeste     éco         [0, 0, 0, 5, 49]
# 98                  très peu cher     éco         [0, 0, 5, 22, 3]
# 99                          truffe   cher        [0, 0, 0, 0, 123]
# 100                  un bon repas    cher        [0, 0, 1, 6, 124]
# 101      un endroit en plein Paris   cher  [1, 125, 126, 127, 128]
# 102       un menu moins de quinze     éco        [1, 48, 9, 4, 50]
# 103               un plat à vingt    cher      [0, 1, 129, 25, 14]
# 104                  un portuguais    éco        [0, 0, 0, 1, 130]
# 105            un restau bien côté   cher      [0, 1, 23, 21, 131]
# 106       un restau dans la creuse    éco    [1, 23, 132, 15, 133]
# 107           un restau de qualité   cher        [0, 1, 23, 4, 16]
# 108        un restau pour conclure   cher      [0, 1, 23, 17, 134]
# 109       un restaurant de routier    éco         [0, 1, 7, 4, 55]
# 110           un restaurant étoilé   cher        [0, 0, 1, 7, 135]
# 111       un resto pour le gratin    cher    [1, 136, 17, 19, 137]
# 112                       un self     éco        [0, 0, 0, 1, 138]
# 113                   un très bon    cher          [0, 0, 1, 5, 6]
# 114              un truc abordable    éco       [0, 0, 1, 33, 139]
# 115                un truc chicos    cher       [0, 0, 1, 33, 140]
# 116                 un truc classe   cher        [0, 0, 1, 33, 36]
# 117                       vil prix    éco       [0, 0, 0, 141, 11]
# 118                   vraiment bon   cher         [0, 0, 0, 24, 6]
# 119               vraiment luxueux   cher        [0, 0, 0, 24, 47]
# 120              vraiment pas cher    éco         [0, 0, 24, 2, 3]
# 121             vraiment très cher   cher         [0, 0, 24, 5, 3]
# 122                      peu cher     éco         [0, 0, 0, 22, 3]
# 123  pas plus de cent par personne   cher    [58, 4, 29, 142, 143]
# 124  plutôt spacieux et tranquille   cher    [0, 10, 144, 30, 145]
# 125                        du bio   moyen       [0, 0, 0, 18, 146]
# 126                         huitre   cher        [0, 0, 0, 0, 147]
# 127      un restaurant de poissons   cher        [0, 1, 7, 4, 148]
# 128           un restaurant rapide    éco         [0, 0, 1, 7, 59]
# 129            un grand restaurant   cher         [0, 0, 1, 62, 7]
# 130           un restaurant grand    cher         [0, 0, 1, 7, 62]
# 131                     prix moyen  moyen        [0, 0, 0, 11, 51]
# 132             mauvais restaurant    éco        [0, 0, 0, 149, 7]
# 133            je veux bien manger   cher     [0, 8, 150, 21, 151]
# 134             des produits frais   cher      [0, 0, 20, 63, 152]
# 135                   des produits   flou        [0, 0, 0, 20, 63]
# 136                     des pizzas    éco       [0, 0, 0, 20, 153]
# 137    un restaurant avec terrasse   cher       [0, 1, 7, 64, 154]
# 138    un restaurant avec ambiance   cher       [0, 1, 7, 64, 155]

# %% [markdown]
# # Préparer la couche d'intégration ( the Embedding layer)
#
# Il s'agit de construire une matrice (nombre de mots x vecteur de 300) qui permette de retrouver le vecteur de chacun des mots du vocabulaire et dinitialiser la couche d'intégration.
#
# Un des problèmes rencontré est que faire lorsque le token ne fait pas parti des mots pré-vectorisés.
#
# PLusieurs solutions étainet possibles on est parti pour attrapper l'erreur en cas de mot ou-of-the-vocabulary en le remplacant par le mot inconnu.
#
# Il restera à tester d'autres familles de wrapper de textfast qui malgré que le mot soit ou-of-vacubalary arrive à lui générer un vecteur, il faudra comprendre lequel et pourquoi !!.

# %%
# prepare embedding matrix
EMBEDDING_DIM = 300
num_words = min(MAX_NUM_WORDS, len(word_index))
print(num_words)
embedding_matrix = np.zeros((num_words + 1, EMBEDDING_DIM))
for word, i in word_index.items():
    # words not found in embedding index will be all-zeros.
    print (word,i)
    try:
        embedding_vector = fr_model[word]
    except KeyError:
        # word not found 
        embedding_vector = embedding_vector
    embedding_matrix[i]=embedding_vector
      


print(embedding_matrix.shape)
embedding_matrix
# Out:
# 155
# un 1
# pas 2
# cher 3
# de 4
# très 5
# bon 6
# restaurant 7
# je 8
# moins 9
# plutôt 10
# prix 11
# gamme 12
# euros 13
# vingt 14
# la 15
# qualité 16
# pour 17
# du 18
# le 19
# des 20
# bien 21
# peu 22
# restau 23
# vraiment 24
# à 25
# bas 26
# marché 27
# burger 28
# cent 29
# et 30
# haut 31
# fiche 32
# truc 33
# modique 34
# japonais 35
# classe 36
# cantine 37
# deux 38
# dix 39
# économique 40
# entre 41
# trente 42
# les 43
# j'aime 44
# m’en 45
# m'en 46
# luxueux 47
# menu 48
# modeste 49
# quinze 50
# moyen 51
# ni 52
# tout 53
# trop 54
# routier 55
# petit 56
# troquet 57
# plus 58
# rapide 59
# standing 60
# super 61
# grand 62
# produits 63
# avec 64
# bonne 65
# franquette 66
# aucun 67
# problème 68
# d'argent 69
# avantageux 70
# bistrot 71
# rapport 72
# caviar 73
# ce 74
# n'est 75
# important 76
# c'est 77
# fin 78
# mois 79
# éco 80
# 10 81
# 20 82
# frites 83
# gastronomique 84
# j’ai 85
# moyens 86
# king 87
# œufs 88
# fous 89
# n'ai 90
# sou 91
# suis 92
# riche 93
# jusqu'à 94
# cinquante 95
# kebab 96
# meilleur 97
# meilleurs 98
# luxe 99
# ma 100
# bourse 101
# est 102
# pleine 103
# mac 104
# do 105
# maccaroni 106
# midi 107
# chic 108
# trois 109
# étoiles 110
# une 111
# pates 112
# bistro 113
# petite 114
# brasserie 115
# importe 116
# onéreux 117
# pizza 118
# mal 119
# ramen 120
# soupe 121
# sushis 122
# truffe 123
# repas 124
# endroit 125
# en 126
# plein 127
# paris 128
# plat 129
# portuguais 130
# côté 131
# dans 132
# creuse 133
# conclure 134
# étoilé 135
# resto 136
# gratin 137
# self 138
# abordable 139
# chicos 140
# vil 141
# par 142
# personne 143
# spacieux 144
# tranquille 145
# bio 146
# huitre 147
# poissons 148
# mauvais 149
# veux 150
# manger 151
# frais 152
# pizzas 153
# terrasse 154
# ambiance 155
# (156, 300)
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.19326   , -0.023721  ,  0.0096097 , ...,  0.22441   ,
#         -0.20043001,  0.15966   ],
#        [ 0.087169  , -0.042794  , -0.044115  , ...,  0.27595001,
#          0.074523  ,  0.16216999],
#        ...,
#        [-0.22148   ,  0.019692  , -0.08569   , ..., -0.17587   ,
#          0.21257   ,  0.052583  ],
#        [-0.035705  ,  0.42269   , -0.52911001, ...,  0.1505    ,
#          0.15895   , -0.060457  ],
#        [-0.33131   , -0.11218   , -0.20186999, ...,  0.25556999,
#          0.17278001,  0.22938   ]])

# %%
# load pre-trained word embeddings into an Embedding layer
# note that we set trainable = False so as to keep the embeddings fixed
embedding_layer = Embedding(num_words + 1,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix],
                            input_length=MAX_SEQUENCE_LENGTH,
                            trainable=False)

# %% [markdown]
# Le prochain pavé permet de transformer les catégories "éco","moyen" et cher en vecteur.
# Ces vecteurs sont rangés dans la colonne 'Ycodes' du dataset

# %%
# encode class values as integers
encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
# convert integers to dummy variables (i.e. one hot encoded)
dummy_y = np_utils.to_categorical(encoded_Y)
dataset['Ycodes'] = pd.Series(list(dummy_y))
dataset
# Out:
#                               text  class                   tokens                Ycodes
# 0            à la bonne franquette    éco      [0, 25, 15, 65, 66]  [0.0, 0.0, 0.0, 1.0]
# 1                  à prix modique     éco       [0, 0, 25, 11, 34]  [0.0, 0.0, 0.0, 1.0]
# 2          aucun problème d'argent   cher       [0, 0, 67, 68, 69]  [1.0, 0.0, 0.0, 0.0]
# 3                      avantageux     éco         [0, 0, 0, 0, 70]  [0.0, 0.0, 0.0, 1.0]
# 4                    bas de gamme     éco        [0, 0, 26, 4, 12]  [0.0, 0.0, 0.0, 1.0]
# 5                         bas prix    éco        [0, 0, 0, 26, 11]  [0.0, 0.0, 0.0, 1.0]
# 6                bistrot pas cher     éco         [0, 0, 71, 2, 3]  [0.0, 0.0, 0.0, 1.0]
# 7                              bon   cher          [0, 0, 0, 0, 6]  [1.0, 0.0, 0.0, 0.0]
# 8                     bon japonais   cher         [0, 0, 0, 6, 35]  [1.0, 0.0, 0.0, 0.0]
# 9                      bon marché     éco         [0, 0, 0, 6, 27]  [0.0, 0.0, 0.0, 1.0]
# 10       bon rapport qualité prix   moyen       [0, 6, 72, 16, 11]  [0.0, 0.0, 1.0, 0.0]
# 11                         burger     éco         [0, 0, 0, 0, 28]  [0.0, 0.0, 0.0, 1.0]
# 12                   burger classe  moyen        [0, 0, 0, 28, 36]  [0.0, 0.0, 1.0, 0.0]
# 13                         cantine    éco         [0, 0, 0, 0, 37]  [0.0, 0.0, 0.0, 1.0]
# 14                         caviar    cher         [0, 0, 0, 0, 73]  [1.0, 0.0, 0.0, 0.0]
# 15          ce n'est pas important  moyen       [0, 74, 75, 2, 76]  [0.0, 0.0, 1.0, 0.0]
# 16           cent euros pour deux    cher      [0, 29, 13, 17, 38]  [1.0, 0.0, 0.0, 0.0]
# 17            c'est la fin du mois    éco     [77, 15, 78, 18, 79]  [0.0, 0.0, 0.0, 1.0]
# 18                           cher    cher          [0, 0, 0, 0, 3]  [1.0, 0.0, 0.0, 0.0]
# 19             dix euros pour deux    éco      [0, 39, 13, 17, 38]  [0.0, 0.0, 0.0, 1.0]
# 20                             éco    éco         [0, 0, 0, 0, 80]  [0.0, 0.0, 0.0, 1.0]
# 21                     économique     éco         [0, 0, 0, 0, 40]  [0.0, 0.0, 0.0, 1.0]
# 22                  entre 10 et 20    éco      [0, 41, 81, 30, 82]  [0.0, 0.0, 0.0, 1.0]
# 23           entre vingt et trente  moyen      [0, 41, 14, 30, 42]  [0.0, 0.0, 1.0, 0.0]
# 24                          frites    éco         [0, 0, 0, 0, 83]  [0.0, 0.0, 0.0, 1.0]
# 25                  gastronomique    cher         [0, 0, 0, 0, 84]  [1.0, 0.0, 0.0, 0.0]
# 26                  haut de gamme    cher        [0, 0, 31, 4, 12]  [1.0, 0.0, 0.0, 0.0]
# 27                j’ai les moyens    cher       [0, 0, 85, 43, 86]  [1.0, 0.0, 0.0, 0.0]
# 28              j'aime burger king    éco       [0, 0, 44, 28, 87]  [0.0, 0.0, 0.0, 1.0]
# 29                 j'aime les œufs    éco       [0, 0, 44, 43, 88]  [0.0, 0.0, 0.0, 1.0]
# 30                        japonais    éco         [0, 0, 0, 0, 35]  [0.0, 0.0, 0.0, 1.0]
# 31                  je m’en fiche    cher        [0, 0, 8, 45, 32]  [1.0, 0.0, 0.0, 0.0]
# 32                   je m’en fous    cher        [0, 0, 8, 45, 89]  [1.0, 0.0, 0.0, 0.0]
# 33                   je m'en fiche  moyen        [0, 0, 8, 46, 32]  [0.0, 0.0, 1.0, 0.0]
# 34                   je m'en fiche  moyen        [0, 0, 8, 46, 32]  [0.0, 0.0, 1.0, 0.0]
# 35              je n'ai pas un sou    éco        [8, 90, 2, 1, 91]  [0.0, 0.0, 0.0, 1.0]
# 36                  je suis riche    cher        [0, 0, 8, 92, 93]  [1.0, 0.0, 0.0, 0.0]
# 37               jusqu'à cinquante   cher        [0, 0, 0, 94, 95]  [1.0, 0.0, 0.0, 0.0]
# 38                           kebab    éco         [0, 0, 0, 0, 96]  [0.0, 0.0, 0.0, 1.0]
# 39       le meilleur des meilleurs   cher      [0, 19, 97, 20, 98]  [1.0, 0.0, 0.0, 0.0]
# 40                           luxe    cher         [0, 0, 0, 0, 99]  [1.0, 0.0, 0.0, 0.0]
# 41                        luxueux    cher         [0, 0, 0, 0, 47]  [1.0, 0.0, 0.0, 0.0]
# 42           ma bourse est pleine    cher  [0, 100, 101, 102, 103]  [1.0, 0.0, 0.0, 0.0]
# 43                          mac do    éco      [0, 0, 0, 104, 105]  [0.0, 0.0, 0.0, 1.0]
# 44                       maccaroni    éco        [0, 0, 0, 0, 106]  [0.0, 0.0, 0.0, 1.0]
# 45          menu pas cher le midi     éco      [48, 2, 3, 19, 107]  [0.0, 0.0, 0.0, 1.0]
# 46                        modeste     éco         [0, 0, 0, 0, 49]  [0.0, 0.0, 0.0, 1.0]
# 47                        modique     éco         [0, 0, 0, 0, 34]  [0.0, 0.0, 0.0, 1.0]
# 48            moins de cent euros    cher        [0, 9, 4, 29, 13]  [1.0, 0.0, 0.0, 0.0]
# 49             moins de dix euros     éco        [0, 9, 4, 39, 13]  [0.0, 0.0, 0.0, 1.0]
# 50                 moins de quinze    éco         [0, 0, 9, 4, 50]  [0.0, 0.0, 0.0, 1.0]
# 51          moins de trente euros   moyen        [0, 9, 4, 42, 13]  [0.0, 0.0, 1.0, 0.0]
# 52                 moins de vingt     éco         [0, 0, 9, 4, 14]  [0.0, 0.0, 0.0, 1.0]
# 53           moins de vingt euros     éco        [0, 9, 4, 14, 13]  [0.0, 0.0, 0.0, 1.0]
# 54                  moyen de gamme  moyen        [0, 0, 51, 4, 12]  [0.0, 0.0, 1.0, 0.0]
# 55            ni cher ni pas cher   moyen        [52, 3, 52, 2, 3]  [0.0, 0.0, 1.0, 0.0]
# 56                   pas bien cher    éco         [0, 0, 2, 21, 3]  [0.0, 0.0, 0.0, 1.0]
# 57                  pas bon marché   cher         [0, 0, 2, 6, 27]  [1.0, 0.0, 0.0, 0.0]
# 58                       pas cher     éco          [0, 0, 0, 2, 3]  [0.0, 0.0, 0.0, 1.0]
# 59                pas cher du tout    éco        [0, 2, 3, 18, 53]  [0.0, 0.0, 0.0, 1.0]
# 60               pas cher du tout     éco        [0, 2, 3, 18, 53]  [0.0, 0.0, 0.0, 1.0]
# 61                        pas chic    éco        [0, 0, 0, 2, 108]  [0.0, 0.0, 0.0, 1.0]
# 62                    pas pas cher   cher          [0, 0, 2, 2, 3]  [1.0, 0.0, 0.0, 0.0]
# 63                pas pas pas cher    éco          [0, 2, 2, 2, 3]  [0.0, 0.0, 0.0, 1.0]
# 64                   pas trop cher    éco         [0, 0, 2, 54, 3]  [0.0, 0.0, 0.0, 1.0]
# 65                   pas trop cher    éco         [0, 0, 2, 54, 3]  [0.0, 0.0, 0.0, 1.0]
# 66                  pas un routier   cher         [0, 0, 2, 1, 55]  [1.0, 0.0, 0.0, 0.0]
# 67           pas un trois étoiles   moyen      [0, 2, 1, 109, 110]  [0.0, 0.0, 1.0, 0.0]
# 68                 pas une cantine   cher       [0, 0, 2, 111, 37]  [1.0, 0.0, 0.0, 0.0]
# 69                           pates    éco        [0, 0, 0, 0, 112]  [0.0, 0.0, 0.0, 1.0]
# 70                    petit bistro    éco       [0, 0, 0, 56, 113]  [0.0, 0.0, 0.0, 1.0]
# 71                   petit troquet    éco        [0, 0, 0, 56, 57]  [0.0, 0.0, 0.0, 1.0]
# 72                petite brasserie    éco      [0, 0, 0, 114, 115]  [0.0, 0.0, 0.0, 1.0]
# 73            peu importe le prix   moyen     [0, 22, 116, 19, 11]  [0.0, 0.0, 1.0, 0.0]
# 74                     peu onéreux    éco       [0, 0, 0, 22, 117]  [0.0, 0.0, 0.0, 1.0]
# 75                           pizza    éco        [0, 0, 0, 0, 118]  [0.0, 0.0, 0.0, 1.0]
# 76                  plus de vingt    cher        [0, 0, 58, 4, 14]  [1.0, 0.0, 0.0, 0.0]
# 77                     plutôt bien   cher        [0, 0, 0, 10, 21]  [1.0, 0.0, 0.0, 0.0]
# 78                     plutôt cher   cher         [0, 0, 0, 10, 3]  [1.0, 0.0, 0.0, 0.0]
# 79            plutôt de la qualité   cher       [0, 10, 4, 15, 16]  [1.0, 0.0, 0.0, 0.0]
# 80                 plutôt pas cher    éco         [0, 0, 10, 2, 3]  [0.0, 0.0, 0.0, 1.0]
# 81                  plutôt pas mal   cher       [0, 0, 10, 2, 119]  [1.0, 0.0, 0.0, 0.0]
# 82              plutôt un troquet     éco        [0, 0, 10, 1, 57]  [0.0, 0.0, 0.0, 1.0]
# 83                         qualité   cher         [0, 0, 0, 0, 16]  [1.0, 0.0, 0.0, 0.0]
# 84                           ramen    éco        [0, 0, 0, 0, 120]  [0.0, 0.0, 0.0, 1.0]
# 85                          rapide    éco         [0, 0, 0, 0, 59]  [0.0, 0.0, 0.0, 1.0]
# 86                           soupe    éco        [0, 0, 0, 0, 121]  [0.0, 0.0, 0.0, 1.0]
# 87                       standing    cher         [0, 0, 0, 0, 60]  [1.0, 0.0, 0.0, 0.0]
# 88                      super cher   cher         [0, 0, 0, 61, 3]  [1.0, 0.0, 0.0, 0.0]
# 89                 super standing    cher        [0, 0, 0, 61, 60]  [1.0, 0.0, 0.0, 0.0]
# 90                          sushis    éco        [0, 0, 0, 0, 122]  [0.0, 0.0, 0.0, 1.0]
# 91               très bas de gamme    éco        [0, 5, 26, 4, 12]  [0.0, 0.0, 0.0, 1.0]
# 92                très bon marché     éco         [0, 0, 5, 6, 27]  [0.0, 0.0, 0.0, 1.0]
# 93                       très cher   cher          [0, 0, 0, 5, 3]  [1.0, 0.0, 0.0, 0.0]
# 94                 très économique    éco         [0, 0, 0, 5, 40]  [0.0, 0.0, 0.0, 1.0]
# 95              très haut de gamme   cher        [0, 5, 31, 4, 12]  [1.0, 0.0, 0.0, 0.0]
# 96              très haut de gamme   cher        [0, 5, 31, 4, 12]  [1.0, 0.0, 0.0, 0.0]
# 97                   très modeste     éco         [0, 0, 0, 5, 49]  [0.0, 0.0, 0.0, 1.0]
# 98                  très peu cher     éco         [0, 0, 5, 22, 3]  [0.0, 0.0, 0.0, 1.0]
# 99                          truffe   cher        [0, 0, 0, 0, 123]  [1.0, 0.0, 0.0, 0.0]
# 100                  un bon repas    cher        [0, 0, 1, 6, 124]  [1.0, 0.0, 0.0, 0.0]
# 101      un endroit en plein Paris   cher  [1, 125, 126, 127, 128]  [1.0, 0.0, 0.0, 0.0]
# 102       un menu moins de quinze     éco        [1, 48, 9, 4, 50]  [0.0, 0.0, 0.0, 1.0]
# 103               un plat à vingt    cher      [0, 1, 129, 25, 14]  [1.0, 0.0, 0.0, 0.0]
# 104                  un portuguais    éco        [0, 0, 0, 1, 130]  [0.0, 0.0, 0.0, 1.0]
# 105            un restau bien côté   cher      [0, 1, 23, 21, 131]  [1.0, 0.0, 0.0, 0.0]
# 106       un restau dans la creuse    éco    [1, 23, 132, 15, 133]  [0.0, 0.0, 0.0, 1.0]
# 107           un restau de qualité   cher        [0, 1, 23, 4, 16]  [1.0, 0.0, 0.0, 0.0]
# 108        un restau pour conclure   cher      [0, 1, 23, 17, 134]  [1.0, 0.0, 0.0, 0.0]
# 109       un restaurant de routier    éco         [0, 1, 7, 4, 55]  [0.0, 0.0, 0.0, 1.0]
# 110           un restaurant étoilé   cher        [0, 0, 1, 7, 135]  [1.0, 0.0, 0.0, 0.0]
# 111       un resto pour le gratin    cher    [1, 136, 17, 19, 137]  [1.0, 0.0, 0.0, 0.0]
# 112                       un self     éco        [0, 0, 0, 1, 138]  [0.0, 0.0, 0.0, 1.0]
# 113                   un très bon    cher          [0, 0, 1, 5, 6]  [1.0, 0.0, 0.0, 0.0]
# 114              un truc abordable    éco       [0, 0, 1, 33, 139]  [0.0, 0.0, 0.0, 1.0]
# 115                un truc chicos    cher       [0, 0, 1, 33, 140]  [1.0, 0.0, 0.0, 0.0]
# 116                 un truc classe   cher        [0, 0, 1, 33, 36]  [1.0, 0.0, 0.0, 0.0]
# 117                       vil prix    éco       [0, 0, 0, 141, 11]  [0.0, 0.0, 0.0, 1.0]
# 118                   vraiment bon   cher         [0, 0, 0, 24, 6]  [1.0, 0.0, 0.0, 0.0]
# 119               vraiment luxueux   cher        [0, 0, 0, 24, 47]  [1.0, 0.0, 0.0, 0.0]
# 120              vraiment pas cher    éco         [0, 0, 24, 2, 3]  [0.0, 0.0, 0.0, 1.0]
# 121             vraiment très cher   cher         [0, 0, 24, 5, 3]  [1.0, 0.0, 0.0, 0.0]
# 122                      peu cher     éco         [0, 0, 0, 22, 3]  [0.0, 0.0, 0.0, 1.0]
# 123  pas plus de cent par personne   cher    [58, 4, 29, 142, 143]  [1.0, 0.0, 0.0, 0.0]
# 124  plutôt spacieux et tranquille   cher    [0, 10, 144, 30, 145]  [1.0, 0.0, 0.0, 0.0]
# 125                        du bio   moyen       [0, 0, 0, 18, 146]  [0.0, 0.0, 1.0, 0.0]
# 126                         huitre   cher        [0, 0, 0, 0, 147]  [1.0, 0.0, 0.0, 0.0]
# 127      un restaurant de poissons   cher        [0, 1, 7, 4, 148]  [1.0, 0.0, 0.0, 0.0]
# 128           un restaurant rapide    éco         [0, 0, 1, 7, 59]  [0.0, 0.0, 0.0, 1.0]
# 129            un grand restaurant   cher         [0, 0, 1, 62, 7]  [1.0, 0.0, 0.0, 0.0]
# 130           un restaurant grand    cher         [0, 0, 1, 7, 62]  [1.0, 0.0, 0.0, 0.0]
# 131                     prix moyen  moyen        [0, 0, 0, 11, 51]  [0.0, 0.0, 1.0, 0.0]
# 132             mauvais restaurant    éco        [0, 0, 0, 149, 7]  [0.0, 0.0, 0.0, 1.0]
# 133            je veux bien manger   cher     [0, 8, 150, 21, 151]  [1.0, 0.0, 0.0, 0.0]
# 134             des produits frais   cher      [0, 0, 20, 63, 152]  [1.0, 0.0, 0.0, 0.0]
# 135                   des produits   flou        [0, 0, 0, 20, 63]  [0.0, 1.0, 0.0, 0.0]
# 136                     des pizzas    éco       [0, 0, 0, 20, 153]  [0.0, 0.0, 0.0, 1.0]
# 137    un restaurant avec terrasse   cher       [0, 1, 7, 64, 154]  [1.0, 0.0, 0.0, 0.0]
# 138    un restaurant avec ambiance   cher       [0, 1, 7, 64, 155]  [1.0, 0.0, 0.0, 0.0]

# %% [markdown]
# ###MODEL DEFINITION
# Le réseau comprend trois couches.
#
# Chaque phrase est représentée à l'aide d'un vecteur de longueur cinq à l'aide d'un vocabulaire à neuf mots.

# %%
########################### MODEL DEFINITION
# train a 1D convnet with global maxpooling
sequence_input = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32')
embedded_sequences = embedding_layer(sequence_input)
x = Conv1D(128, 5, activation='relu')(embedded_sequences)
x = MaxPooling1D(1)(x)
x = Conv1D(128, 1, activation='relu')(x)
x = MaxPooling1D(1)(x)
x = Conv1D(128, 1, activation='relu')(x)
x = GlobalMaxPooling1D()(x)
x = Dense(128, activation='relu')(x)
preds = Dense(3, activation='softmax')(x)

# %%
model = Model(sequence_input, preds)
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['acc'])

# %%
x_train = data
y_train = dummy_y

model.fit(x_train, y_train,
          batch_size=128,
          epochs=20)
#          validation_data=(x_val, y_val))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-528d390bca9c> in <module>()
#       4 model.fit(x_train, y_train,
#       5           batch_size=128,
# ----> 6           epochs=20)
#       7 #          validation_data=(x_val, y_val))
#       8
#
# d:\code\ml\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1591             class_weight=class_weight,
#    1592             check_batch_axis=False,
# -> 1593             batch_size=batch_size)
#    1594         # Prepare validation data.
#    1595         do_validation = False
#
# d:\code\ml\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_batch_axis, batch_size)
#    1428                                     output_shapes,
#    1429                                     check_batch_axis=False,
# -> 1430                                     exception_prefix='target')
#    1431         sample_weights = _standardize_sample_weights(sample_weight,
#    1432                                                      self._feed_output_names)
#
# d:\code\ml\lib\site-packages\keras\engine\training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     118                             ': expected ' + names[i] + ' to have shape ' +
#     119                             str(shape) + ' but got array with shape ' +
# --> 120                             str(data_shape))
#     121     return data
#     122
#
# ValueError: Error when checking target: expected dense_2 to have shape (3,) but got array with shape (4,)

# %%
###### TRAINING + EVALUATION
x_test = x_train
y_test = y_train
loss,metric = model.evaluate(x_test, y_test)
print ("Loss = ", loss," Accuracy = ",metric)

# %%
dataset['predicted'] = list(model.predict(x_train)) 

def decodeY(L):
	if L[0]>L[1] and L[0]>L[2]: 
		return "cher"
	elif L[2]>L[1] and L[2]>L[0]:
		return "éco"
	else:
		return "moyen"
	
dataset['resultat']=list(map(decodeY,dataset['predicted']))
dataset

# %%
# split the data into a training set and a validation set
VALIDATION_SPLIT = 0.2
labels = dummy_y
indices = np.arange(data.shape[0])
np.random.shuffle(indices)
data = data[indices]
labels = labels[indices]
num_validation_samples = int(VALIDATION_SPLIT * data.shape[0])
x_train = data[:-num_validation_samples]
y_train = labels[:-num_validation_samples]
x_val = data[-num_validation_samples:]
y_val = labels[-num_validation_samples:]

# %%
model.fit(x_train, y_train,
          batch_size=128,
          epochs=50,
          validation_data=(x_val, y_val))

# %%
labels

# %%
dataset['predicted'] = list(model.predict(data)) 

def decodeY(L):
	if L[0]>L[1] and L[0]>L[2]: 
		return "cher"
	elif L[2]>L[1] and L[2]>L[0]:
		return "éco"
	else:
		return "moyen"
	
    

dataset['resultat']=list(map(decodeY,dataset['predicted']))
dataset

# %%
import matplotlib
import matplotlib.pyplot as plt


for x,y,z in dataset['predicted']:
    #print(x,z)
    plt.plot(x,z,'ro')


#plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.axis([-0.1, 1.1, -0.1, 1.1])
plt.show()

# %%
while True:
    inp = input("Tu préfères aller dans un restau plutôt cher ou plutôt pas cher ?(fin pour sortir)")
    if (inp == 'fin'):
        break
    sequences = tokenizer.texts_to_sequences([inp])
    padded_sequence = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
    prediction = model.predict(padded_sequence)
    print(prediction)
    #decodeY(model.predict(pad_sequences(tokenizer.texts_to_sequences(['pas cher']), maxlen=MAX_SEQUENCE_LENGTH))[0]))
    print("ça veut dire ->" ,decodeY(prediction[0]))

# %% [markdown]
# ####
